# %%
import json
import logging
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model, datasets
from sklearn.metrics import f1_score
from nltk.stem.porter import *

from preprocessing import Preprocessor
from data_loader import DataLoader
from doc2vec  import Doc2VecWrapper
from trainer import Trainer, Metrics

#nltk.download('wordnet')
#nltk.download('stopwords')

# %%
if __name__ == "__main__":  
    # Load the data.
    loader = DataLoader()
    with open('settings.json', 'r') as settingsJ:
        settings = json.load(settingsJ)
        train_set, test_set = loader.load_dataset(settings) 
        # Cut it down in size to speed up the test.
        train_set = train_set.iloc[:500]
        test_set = test_set.iloc[:500]

# %%
# Preprocess the data in accordance with settings.
preprocesor = Preprocessor(settings)
train_df = preprocesor.preprocess(train_set)
test_df = preprocesor.preprocess(test_set)
# Out:
# INFO:root:Using WordTokenizer as tokenizer
# INFO:root:Using default lematization
# INFO:root:Using default stemming
# INFO:root:Using default stopwords_remove

# %%
# Train doc2vec model and perform inference.
d2v = Doc2VecWrapper()
d2v.train(train_df, settings)
    
train_vector = d2v.doc2vec_features(train_df)
test_vector = d2v.doc2vec_features(test_df)
# Out:
# INFO:gensim.models.doc2vec:collecting all words and their counts
# INFO:gensim.models.doc2vec:PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# INFO:gensim.models.doc2vec:collected 9260 word types and 500 unique tags from a corpus of 500 examples and 89358 words
# INFO:gensim.models.word2vec:Loading a fresh vocabulary
# INFO:gensim.models.word2vec:effective_min_count=2 retains 5110 unique words (55% of original 9260, drops 4150)
# INFO:gensim.models.word2vec:effective_min_count=2 leaves 85208 word corpus (95% of original 89358, drops 4150)
# INFO:gensim.models.word2vec:deleting the raw counts dictionary of 9260 items
# INFO:gensim.models.word2vec:sample=0 downsamples 0 most-common words
# INFO:gensim.models.word2vec:downsampling leaves estimated 85208 word corpus (100.0% of prior 85208)
# INFO:gensim.models.base_any2vec:estimated required memory for 5110 words and 5000 dimensions: 216955000 bytes
# INFO:gensim.models.word2vec:resetting layer weights
# INFO:gensim.models.doc2vec:collecting all words and their counts
# INFO:gensim.models.doc2vec:PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# INFO:gensim.models.doc2vec:collected 9260 word types and 500 unique tags from a corpus of 500 examples and 89358 words
# INFO:gensim.models.word2vec:Loading a fresh vocabulary
# INFO:gensim.models.word2vec:effective_min_count=2 retains 5110 unique words (55% of original 9260, drops 4150)
# INFO:gensim.models.word2vec:effective_min_count=2 leaves 85208 word corpus (95% of original 89358, drops 4150)
# INFO:gensim.models.word2vec:deleting the raw counts dictionary of 9260 items
# INFO:gensim.models.word2vec:sample=0 downsamples 0 most-common words
# INFO:gensim.models.word2vec:downsampling leaves estimated 85208 word corpus (100.0% of prior 85208)
# INFO:gensim.models.base_any2vec:estimated required memory for 5110 words and 5000 dimensions: 216955000 bytes
# INFO:gensim.models.word2vec:resetting layer weights
# INFO:gensim.models.base_any2vec:training model with 4 workers on 5110 vocabulary and 5000 features, using sg=1 hs=0 sample=0 negative=5 window=5
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 65.20% examples, 56604 words/s, in_qsize 3, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 1 : training on 89358 raw words (85708 effective words) took 1.2s, 72121 effective words/s
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 76.20% examples, 65953 words/s, in_qsize 2, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 2 : training on 89358 raw words (85708 effective words) took 1.2s, 74106 effective words/s
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 100.00% examples, 84586 words/s, in_qsize 0, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 3 : training on 89358 raw words (85708 effective words) took 1.0s, 84503 effective words/s
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 100.00% examples, 76219 words/s, in_qsize 0, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 4 : training on 89358 raw words (85708 effective words) took 1.1s, 76140 effective words/s
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 100.00% examples, 80737 words/s, in_qsize 0, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 5 : training on 89358 raw words (85708 effective words) took 1.1s, 80655 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 64.80% examples, 55750 words/s, in_qsize 4, out_qsize 0
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 6 : training on 89358 raw words (85708 effective words) took 1.2s, 69594 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 66.40% examples, 56686 words/s, in_qsize 4, out_qsize 0
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 7 : training on 89358 raw words (85708 effective words) took 1.1s, 75346 effective words/s
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 100.00% examples, 83502 words/s, in_qsize 0, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 8 : training on 89358 raw words (85708 effective words) took 1.0s, 83418 effective words/s
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:EPOCH 9 - PROGRESS: at 100.00% examples, 83698 words/s, in_qsize 0, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 9 : training on 89358 raw words (85708 effective words) took 1.0s, 83620 effective words/s
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 10 : training on 89358 raw words (85708 effective words) took 1.0s, 87160 effective words/s
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:EPOCH 11 - PROGRESS: at 100.00% examples, 78827 words/s, in_qsize 0, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 11 : training on 89358 raw words (85708 effective words) took 1.1s, 78732 effective words/s
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:EPOCH 12 - PROGRESS: at 100.00% examples, 82214 words/s, in_qsize 0, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 12 : training on 89358 raw words (85708 effective words) took 1.0s, 82138 effective words/s
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 13 : training on 89358 raw words (85708 effective words) took 1.0s, 89191 effective words/s
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 14 : training on 89358 raw words (85708 effective words) took 1.0s, 87808 effective words/s
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 15 : training on 89358 raw words (85708 effective words) took 0.9s, 91339 effective words/s
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:EPOCH 16 - PROGRESS: at 100.00% examples, 84233 words/s, in_qsize 0, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 16 : training on 89358 raw words (85708 effective words) took 1.0s, 84053 effective words/s
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:EPOCH 17 - PROGRESS: at 100.00% examples, 79591 words/s, in_qsize 0, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 17 : training on 89358 raw words (85708 effective words) took 1.1s, 79508 effective words/s
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:EPOCH 18 - PROGRESS: at 100.00% examples, 85393 words/s, in_qsize 0, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 18 : training on 89358 raw words (85708 effective words) took 1.0s, 85311 effective words/s
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 19 : training on 89358 raw words (85708 effective words) took 1.0s, 86994 effective words/s
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 20 : training on 89358 raw words (85708 effective words) took 1.0s, 86129 effective words/s
# INFO:gensim.models.base_any2vec:training on a 1787160 raw words (1714160 effective words) took 21.1s, 81080 effective words/s
# INFO:gensim.models.base_any2vec:training model with 4 workers on 5110 vocabulary and 5000 features, using sg=0 hs=0 sample=0 negative=5 window=10
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 54.80% examples, 33503 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 1 : training on 89358 raw words (85708 effective words) took 1.8s, 46692 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 53.60% examples, 34779 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 2 : training on 89358 raw words (85708 effective words) took 1.7s, 49134 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 54.80% examples, 34817 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 3 : training on 89358 raw words (85708 effective words) took 1.8s, 48820 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 43.60% examples, 32499 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 4 : training on 89358 raw words (85708 effective words) took 2.1s, 40221 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 53.60% examples, 36704 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 5 : training on 89358 raw words (85708 effective words) took 1.7s, 50929 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 53.60% examples, 35679 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 6 : training on 89358 raw words (85708 effective words) took 1.7s, 50064 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 53.60% examples, 36220 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 7 : training on 89358 raw words (85708 effective words) took 1.7s, 50600 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 54.80% examples, 33840 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 8 : training on 89358 raw words (85708 effective words) took 1.8s, 47113 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 9 - PROGRESS: at 53.60% examples, 32737 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 9 : training on 89358 raw words (85708 effective words) took 1.9s, 45793 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 10 - PROGRESS: at 53.60% examples, 33987 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 10 : training on 89358 raw words (85708 effective words) took 1.8s, 47760 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 11 - PROGRESS: at 53.60% examples, 33313 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 11 : training on 89358 raw words (85708 effective words) took 1.8s, 47927 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 12 - PROGRESS: at 53.60% examples, 34629 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 12 : training on 89358 raw words (85708 effective words) took 1.8s, 47873 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 13 - PROGRESS: at 54.80% examples, 33187 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 13 : training on 89358 raw words (85708 effective words) took 1.8s, 47197 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 14 - PROGRESS: at 54.80% examples, 33559 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 14 : training on 89358 raw words (85708 effective words) took 1.9s, 45744 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 15 - PROGRESS: at 53.60% examples, 32454 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 15 : training on 89358 raw words (85708 effective words) took 1.8s, 46635 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 16 - PROGRESS: at 54.80% examples, 32861 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 16 : training on 89358 raw words (85708 effective words) took 1.9s, 45856 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 17 - PROGRESS: at 53.60% examples, 32247 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 17 : training on 89358 raw words (85708 effective words) took 1.9s, 45436 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 18 - PROGRESS: at 53.60% examples, 32202 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 18 : training on 89358 raw words (85708 effective words) took 1.8s, 46763 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 19 - PROGRESS: at 53.60% examples, 34891 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 19 : training on 89358 raw words (85708 effective words) took 1.8s, 46665 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 20 - PROGRESS: at 53.60% examples, 32357 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 20 : training on 89358 raw words (85708 effective words) took 1.9s, 45498 effective words/s
# INFO:gensim.models.base_any2vec:training on a 1787160 raw words (1714160 effective words) took 36.6s, 46878 effective words/s

# %%
# Train and evaluate classification model.          
t = Trainer(settings)
m = Metrics.MetricEvaluator(settings)

t.fit(train_vector, train_set)
pred = t.predict(test_vector)
results = m.evaluate(test_set, pred)

print(results)
# Out:
# INFO:root:Training m1
# INFO:root:Training m2
# INFO:root:Using f1_score metric
# INFO:root:Evaluating m1
# INFO:root:Evaluating m2
# [('m1', 0.33), ('m2', 0.382)]
